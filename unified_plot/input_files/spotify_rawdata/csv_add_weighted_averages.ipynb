# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import re, glob
import os, sys
from scipy import stats

# %%
# Input track list per country
country_tracks_data_df = pd.read_csv("Spain_tracks_with_audio_features.csv")
country_tracks_data_df.head()
# Out:
#    Position         Track Name        Artist  Streams  \
# 0         1            Secreto      Anuel AA  2888172
# 1         2  Baila Baila Baila         Ozuna  2693711
# 2         3         Adan y Eva  Paulo Londra  2448248
# 3         4      Calma - Remix    Pedro Capó  2216229
# 4         5     NI BIEN NI MAL     Bad Bunny  2082242
#
#                                                  URL  Year  Month  yyyy-mm  \
# 0  https://open.spotify.com/track/5W83ErFkO3aKAIS...  2019      1  2019-01
# 1  https://open.spotify.com/track/7uH27oIt4a6cIFC...  2019      1  2019-01
# 2  https://open.spotify.com/track/6FyRXC8tJUh863J...  2019      1  2019-01
# 3  https://open.spotify.com/track/5iwz1NiezX7WWjn...  2019      1  2019-01
# 4  https://open.spotify.com/track/278kSqsZIiYp8p3...  2019      1  2019-01
#
#    Stream %                Track ID  Danceability  Valence  Energy    Tempo  \
# 0  0.028116  5W83ErFkO3aKAIS1WMi6u0         0.807    0.706   0.803   91.987
# 1  0.026223  7mWFF4gPADjTQjC97CgFVt         0.785    0.490   0.572  100.016
# 2  0.023833  6FyRXC8tJUh863JCkyWqtk         0.767    0.720   0.709  171.993
# 3  0.021575  5iwz1NiezX7WWjnCgY5TH4         0.826    0.761   0.773  126.899
# 4  0.020270  278kSqsZIiYp8p3QjYAqa8         0.826    0.337   0.449  128.028
#
#    Danceability_Stream%  Valence_Stream%  Energy_Stream%  Tempo_Stream%
# 0              0.022690         0.019850        0.022577       2.586315
# 1              0.020585         0.012849        0.015000       2.622722
# 2              0.018280         0.017160        0.016898       4.099190
# 3              0.017821         0.016418        0.016677       2.737819
# 4              0.016743         0.006831        0.009101       2.595183

# %%
country_spotify_groupby = country_tracks_data_df.groupby(["Year", 'Month'], as_index=False)['Danceability_Stream%', 'Valence_Stream%', 'Energy_Stream%'].sum()
country_spotify_groupby
# Out:
# <ipython-input-22-9ad7a06e2432>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   country_spotify_groupby = country_tracks_data_df.groupby(["Year", 'Month'], as_index=False)['Danceability_Stream%', 'Valence_Stream%', 'Energy_Stream%'].sum()
#     Year  Month  Danceability_Stream%  Valence_Stream%  Energy_Stream%
# 0   2019      1              0.732937         0.581459        0.684302
# 1   2019      2              0.746851         0.587998        0.681939
# 2   2019      3              0.744042         0.605634        0.684124
# 3   2019      4              0.735087         0.611994        0.676191
# 4   2019      5              0.725942         0.616415        0.687066
# 5   2019      6              0.718146         0.612641        0.670098
# 6   2019      7              0.727508         0.639680        0.685621
# 7   2019      8              0.732725         0.624939        0.682709
# 8   2019      9              0.733598         0.628366        0.677609
# 9   2019     10              0.734195         0.639074        0.673557
# 10  2019     11              0.737486         0.622908        0.677617
# 11  2019     12              0.708846         0.607028        0.658631
# 12  2020      1              0.725127         0.625140        0.676374
# 13  2020      2              0.737580         0.595780        0.669211
# 14  2020      3              0.744913         0.632578        0.693769
# 15  2020      4              0.740126         0.629511        0.703345
# 16  2020      5              0.748140         0.614825        0.692628
# 17  2020      6              0.752669         0.641679        0.706560
# 18  2020      7              0.735062         0.637669        0.693188
# 19  2020      8              0.719757         0.616821        0.680289
# 20  2020      9              0.716115         0.624891        0.681794
# 21  2020     10              0.713063         0.617730        0.671358
# 22  2020     11              0.722497         0.584769        0.665292
# 23  2020     12              0.713305         0.608028        0.665876

# %%
country_spotify_groupby.to_csv("../spotify_weighted/Spain_Weighted_tracks_with_audio_features.csv")

# %%
# # Obtain total streams per month
# total_sum = country_tracks_data_df.groupby(['Year','Month']).Streams.sum()
# # Create data frame
# data = pd.DataFrame(total_sum)
# # Magic
# my_data = pd.DataFrame(data.to_records())

# my_data.head()
# Out:
#    Year  Month   Streams
# 0  2019      1  17016137
# 1  2019      2  17065715
# 2  2019      3  15840837
# 3  2019      4  15354252
# 4  2019      5  15997780

# %%
# # Merge total streams per month to original file in column Streams_y
# next_step = country_tracks_data_df.merge(my_data, how='inner', left_on=['Year', 'Month'], right_on=['Year', 'Month'])
# next_step.head()
# Out:
#    Position                                     Track Name         Artist  \
# 0         1                                        7 rings  Ariana Grande
# 1         2  Sunflower - Spider-Man: Into the Spider-Verse    Post Malone
# 2         3                                           Wow.    Post Malone
# 3         4                                     Without Me         Halsey
# 4         5                               Sweet but Psycho        Ava Max
#
#    Streams_x                                                URL  Year  Month  \
# 0     562985  https://open.spotify.com/track/14msK75pk3pA33p...  2019      1
# 1     389293  https://open.spotify.com/track/3KkXRkHbMCARz0a...  2019      1
# 2     345858  https://open.spotify.com/track/6MWtB6iiXyIwun0...  2019      1
# 3     280760  https://open.spotify.com/track/5p7ujcrUXASCNwR...  2019      1
# 4     276126  https://open.spotify.com/track/25sgk305KZfyuqV...  2019      1
#
#                  Track ID  Danceability  Valence  Energy  Streams_y
# 0  6ocbgoVGwYJhOv1GgI9NsF         0.778    0.317   0.327   17016137
# 1  3KkXRkHbMCARz0aVfEt68P         0.760    0.479   0.913   17016137
# 2  7xQAfvXzm3AkraOtGPWIZg         0.829    0.539   0.388   17016137
# 3  7lQ8MOhq6IN2w8EYcFNSUk         0.908    0.669   0.662   17016137
# 4  7DnAm9FOTWE3cUvso43HhI         0.720    0.706   0.620   17016137

# %%
# # Calculate new columns
# next_step['Danceability %'] = next_step['Danceability']*next_step['Streams_x']/next_step['Streams_y']
# next_step['Energy %'] = next_step['Energy']*next_step['Streams_x']/next_step['Streams_y']
# next_step['Valence %'] = next_step['Valence']*next_step['Streams_x']/next_step['Streams_y']
# next_step.head()
# Out:
#    Position                                     Track Name         Artist  \
# 0         1                                        7 rings  Ariana Grande
# 1         2  Sunflower - Spider-Man: Into the Spider-Verse    Post Malone
# 2         3                                           Wow.    Post Malone
# 3         4                                     Without Me         Halsey
# 4         5                               Sweet but Psycho        Ava Max
#
#    Streams_x                                                URL  Year  Month  \
# 0     562985  https://open.spotify.com/track/14msK75pk3pA33p...  2019      1
# 1     389293  https://open.spotify.com/track/3KkXRkHbMCARz0a...  2019      1
# 2     345858  https://open.spotify.com/track/6MWtB6iiXyIwun0...  2019      1
# 3     280760  https://open.spotify.com/track/5p7ujcrUXASCNwR...  2019      1
# 4     276126  https://open.spotify.com/track/25sgk305KZfyuqV...  2019      1
#
#                  Track ID  Danceability  Valence  Energy  Streams_y  \
# 0  6ocbgoVGwYJhOv1GgI9NsF         0.778    0.317   0.327   17016137
# 1  3KkXRkHbMCARz0aVfEt68P         0.760    0.479   0.913   17016137
# 2  7xQAfvXzm3AkraOtGPWIZg         0.829    0.539   0.388   17016137
# 3  7lQ8MOhq6IN2w8EYcFNSUk         0.908    0.669   0.662   17016137
# 4  7DnAm9FOTWE3cUvso43HhI         0.720    0.706   0.620   17016137
#
#    Danceability %  Energy %  Valence %
# 0        0.025740  0.010819   0.010488
# 1        0.017387  0.020887   0.010959
# 2        0.016850  0.007886   0.010955
# 3        0.014982  0.010923   0.011038
# 4        0.011684  0.010061   0.011456

# %%
# # Generate final file

# last_step = next_step.groupby(["Year", 'Month'], as_index=False)[['Danceability %','Energy %', 'Valence %']].sum()

# last_step.head()
# Out:
#    Year  Month  Danceability %  Energy %  Valence %
# 0  2019      1        0.690073  0.464874   0.600466
# 1  2019      2        0.685002  0.441264   0.588278
# 2  2019      3        0.686947  0.457023   0.588093
# 3  2019      4        0.694459  0.481932   0.566785
# 4  2019      5        0.694453  0.491478   0.587496

# %%
last_step.to_csv("New Zealand_Weighted_tracks_with_audio_features.csv")
