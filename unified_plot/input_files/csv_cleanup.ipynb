# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import re, glob
import os, sys
from scipy import stats

# %%
country_tracks_data_df = pd.read_csv("Germany_FIX_tracks_with_audio_features.csv")

country_tracks_data_df.head()
# Out:
#    Unnamed: 0  Position                Track Name       Artist  Streams  \
# 0           0         1               Hobby Hobby         MERO  7774110
# 1           1         2                      DODI       Shindy  3942856
# 2           2         3                   Benzema  Capital Bra  3592118
# 3           3         4  Wenn die Sonne untergeht         Azet  3366951
# 4           4         5                   Warnung     Kontra K  3063451
#
#                                                  URL  Year  Month  \
# 0  https://open.spotify.com/track/260R90ctQ1SiPax...  2019      1
# 1  https://open.spotify.com/track/63THFs9ovzO3WQs...  2019      1
# 2  https://open.spotify.com/track/7KPGeiXWDsGEvFK...  2019      1
# 3  https://open.spotify.com/track/23N0z3XkwS2ErcN...  2019      1
# 4  https://open.spotify.com/track/3OgD9c7c6GhEWUK...  2019      1
#
#                  Track ID  Danceability  Energy  Valence  Stream %  \
# ...

# %%
cor_country_tracks_data_df.to_csv("Germany_tracks_with_audio_features.csv", index = False)
